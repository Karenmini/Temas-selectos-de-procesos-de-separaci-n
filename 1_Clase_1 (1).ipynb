# %% [markdown]
# ***Semana 1-Clase 1- 19/01/2026***

# %% [markdown]
# **Nombre:** Karen Gabriela Rodríguez Corona

# %% [markdown]
# Esta clase fue una introducción, en donde se tomaron temas como:
#
# ¿**Qué es un lenguaje de programación?**
#
# Conjunto de reglas y símbolos para dar instrucciones a la computadora.
#
# Este lenguaje tiene sus propias reglas para poder funcionar.
# Las reglas pueden son léxicas, sintácticas y semánticas.
#
# **¿Qué es Python?**
#
# Lenguaje de programación popular.
#
# Su principal uso es en:
#
#
# *   Aplicaciones web
# *   Desarrollo de software
#
# *   Ciencia de datos Machine Learning
#
# **Análisis de datos**
#
# El análisis de datos es un proceso en el cual se inspecciona, limpia, transforma y modela datos. Su fin es descubrir información útil qqe nos ayuda a la toma de decisiones y concluir un problema.

# %% [markdown]
# **Tipos de datos**
#
# Los tipos de python, también conocidos como datos primitivos son las estructuras de datos más elementales del lenguaje de programación.
#
# Son los siguientes:
#
# 1. **Int:** Se utiliza para números enteros.
# 2. **Float:** Para números decimales.
# 3. **String:** Para formar cadenas de oraciones.
# 4. **Bool (Datos binarios):** Verdadero (true) y Falso (Flase)

# %% [markdown]
# *Ejemplo de datos primitivos*

# %%
a= 2 #Dato primitivo tipo entero
b= 2.5 #Dato primitivo tipo flotante
c= "Amor" #Dato primitivo tipo string
d= True #Dato primitivo tipo booleano

# %% [markdown]
# **Sintáxis**

# %%
nombre=[elemento 1, elemento 2,..., elemento n]

# %%
lista_de_enteros = [1, 20, 33, 56,77]
lista_tipo_cadena = ['arbol', 'gato', 'anillo','lapicero','Karen'] #Recordar: colocar comillas simpls o dobles a la lista tipo cadena.
lista_combinada = ['rata',1,23,'pico',22,'Marco']
listamaslista = ['caja', 'torta',1,3,5,23,[27,33,'mosco','Karla']]
listabien = [lista_de_enteros, 23, 43]

# %%
print(listamaslista)#print te muestra los resultados
lista_combinada
# Out:
# ['caja', 'torta', 1, 3, 5, 23, [27, 33, 'mosco', 'Karla']]
# ['rata', 1, 23, 'pico', 22, 'Marco']

# %%
lista_de_enteros#en esta sección solo llamamos las listas sin el prin, nos da todo.
lista_combinada
lista_tipo_cadena
listabien
listamaslista
# Out:
# ['caja', 'torta', 1, 3, 5, 23, [27, 33, 'mosco', 'Karla']]

# %%
print (lista_de_enteros)
print (lista_combinada)
print (lista_tipo_cadena)
print (listabien)
print (listamaslista)
# Out:
# [1, 20, 33, 56, 77]
# ['rata', 1, 23, 'pico', 22, 'Marco']
# ['arbol', 'gato', 'anillo', 'lapicero', 'Karen']
# [[1, 20, 33, 56, 77], 23, 43]
# ['caja', 'torta', 1, 3, 5, 23, [27, 33, 'mosco', 'Karla']]

# %%
lista_de_enteros#llama la lista 1
# Out:
# [1, 20, 33, 56, 77]

# %% [markdown]
# *Para llamar un dato de una lista*

# %%
lista_combinada[2] #llama al valor de la posición 2 de la lista combinada
# Out:
# 23

# %% [markdown]
# *Para añadir datos*

# %%
lista_de_enteros.append(2305)
lista_de_enteros
# Out:
# [1, 20, 33, 56, 77, 2305, 2305, 2305]

# %% [markdown]
# *¿Cómo quitar datos?*

# %%
lista_combinada.remove('rata') #nombre de la lista.remove (valor a eliminar)
lista_combinada
# Out:
# [1, 23, 22, 'Marco']

# %% [markdown]
# *Cadenas de texto*

# %%
nombre = 'Karencita'
apodo = 'mini '+ nombre
print (apodo)
# Out:
# mini Karencita

# %% [markdown]
# *Las cadenas de texto en Python son inmutables (es deir que no se pueden modificar)*

# %%
a = 'el retorno del rey'
a
# Out:
# 'el retorno del rey'

# %%
a[15]
# Out:
# 'r'

# %% [markdown]
# Si modificamos una cadena de texto, tenemos que utilizar una función que cree una nueva cadena, como la función .replace() para cadenas de texto:

# %%
b = a.replace('rey','gato')
b
# Out:
# 'el retorno del gato'

# %% [markdown]
# Los objetos se pueden transformar en una cadena de texto utilizando la función str ()

# %%
m= 344
m
# Out:
# 344

# %%
k = str (m)
k
# Out:
# '344'

# %% [markdown]
# Sumar dos cadenas las concatena y produce una nueva

# %%
n = 'gaby'
e = str('24')

# %%
n + e
# Out:
# 'gaby24'
